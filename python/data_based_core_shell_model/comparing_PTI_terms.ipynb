# %%
import os
import sys

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# mpl.use("TkCairo")

# %%
    
## Get physical constants from Scipy
import scipy.constants as con
## Some useful numerical constants
hbar = con.physical_constants['Planck constant over 2 pi in eV s'][0]
c = con.physical_constants['speed of light in vacuum'][0]*1e2 #cm/m
# k = con.physical_constants['Boltzmann constant in eV/K'][0]

import scipy.integrate as integ

import scipy.io as sio

import scipy.optimize as opt

import scipy.special as spl

## For loading dielectric data fits
import pickle as pkl

# %%
misloc_pack_path = os.path.join(
    os.path.sep,
    'Users',
    'chair',
    'Documents',
    'Academia',
    'SuperRes',
    'Biteen_colab',
    'Mispolarization',
    'python',
#     'gitted',
    )

sys.path.append(misloc_pack_path)

import misloc_mispol_package as mmp
import misloc_mispol_package.calc.coupled_dipoles as cp
import misloc_mispol_package.optics.anal_foc_diff_fields as aff

# %%
sys.path.append('../modules')
import twosphere_temperature as tst
import pti_model as pti

# %%
## Matplotlib settings
## inspired by http://nipunbatra.github.io/2014/08/latexify/
params = {
    'text.latex.preamble': ['\\usepackage{gensymb}'],
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'magma',
    'axes.grid': False,
    'figure.dpi': 150,  # to adjust notebook inline plot size
    'savefig.dpi': 150,  # to adjust notebook inline plot size
    'axes.labelsize': 12, # fontsize for x and y labels (was 10)
    'axes.titlesize': 14,
    'font.size': 8, # was 10
    'legend.fontsize': 8, # was 10
    'xtick.labelsize': 8,
    'ytick.labelsize': 8,
    'text.usetex': True,
    'figure.figsize': [3.5, 2.625], # 4 x 3
#     'figure.figsize': [4*1.125, 3*1.125], # 4x3, full slide in keynote
    'font.family': 'serif',
    'figure.max_open_warning':100,
    'axes.formatter.limits' : [-3, 3]
}
mpl.rcParams.update(params)

# %% [markdown]
# Path to temperature dependent dielectric data

# %%
path_to_diel_data = os.path.join(
    os.path.sep,
    'Users',
    'chair',
    'Documents',
    'Academia',
    'DMREF',
    'dielectrics'
    )

# %%
os.path.exists(path_to_diel_data)
# Out:
# True

# %%
## Get fit eps parameters dictionary
with open('temp_dep_eps_fits.pkl', 'rb') as handle:
    temp_dep_eps_fits = pkl.load(handle)
## Get fit dndt dictionary
with open('fit_dndt.pkl', 'rb') as handle:
    fit_dndT = pkl.load(handle)

# %%
## Get the dndt array (as 2d function of temperature and frequency)
hws = fit_dndT['hws']
dndt_array = fit_dndT['dndt_array']
dnr_dt_array = dndt_array.real
## -------------------

## Calculate finite difference
dni_dt_array = dndt_array.imag
## -------------------

# %%
a1 = 10
# eps_back = 1.473**2
eps_back = 1.473**2

# %%
def get_self_interf_terms_vs_energy(T_expansion, r_th, w0, phi):
    """ Lengths are input in nm
        """
    if ax is None:
        fig, ax = plt.subplots(1, 1)
    ## Get dielectric function and dn/dT
    fit_drude = cp.drude_lorentz_model(
            hws/hbar, 
            *temp_dep_eps_fits[f'{T_expansion:d}K']['x']
            )
    fit_dndT = dndt_array[:, T_expansion]

    (
        alpha0_term, 
        alphapi2_term, 
        alphaphi_term, 
        alphapi2phi_term
        ) = pti.ptsignal_scattering_self_interf_term(
            eps_c=fit_drude,
            eps_b=eps_back,
            a=a1*1e-7,
            b=w0*1e-7,
            r_th=r_th*1e-7,
            dndT_c= fit_dndT,
            phi=phi,
#             P_abs=None,
#             dndT_b=dndT_glycerol,
#             kappa=kappa_glycerol,
#             E_probe=1,
#             G_=1,
            return_components=True,
            )
    return alpha0_term, alphapi2_term, alphaphi_term, alphapi2phi_term

def plot_self_interf_terms_vs_energy(T_expansion, r_th, w0, phi, ax=None):
    """ Lengths are input in nm
        """
    if ax is None:
        fig, ax = plt.subplots(1, 1)
    ## Get dielectric function and dn/dT
    fit_drude = cp.drude_lorentz_model(
            hws/hbar, 
            *temp_dep_eps_fits[f'{T_expansion:d}K']['x']
            )
    fit_dndT = dndt_array[:, T_expansion]

    (
        alpha0_term, 
        alphapi2_term, 
        alphaphi_term, 
        alphapi2phi_term
        ) = get_self_interf_terms_vs_energy(T_expansion, r_th, w0, phi)
    
    ax.plot(
        hws.real,
        alpha0_term,
        label=r"$\alpha_\Omega^{(0)}$")
    ax.plot(
        hws.real,
        alphapi2_term,
        label=r"$\alpha_\Omega^{\pi/2}$",
        ls='--')
    ax.plot(
        hws.real,
        alphaphi_term,
        label=r"$\alpha_\Omega^{(\phi_{w_0})}$")
    ax.plot(
        hws.real,
        alphapi2phi_term,
        label=r"$\alpha_\Omega^{(\pi/2+\phi_{w_0})}$",
        ls='--')
    ax.plot(
        hws.real,
        (  
            alpha0_term
            +alphapi2_term
            +alphaphi_term
            +alphapi2phi_term),
        label=r"sum",
        c='k')
    ax.legend(loc='center left')
    ax.set_ylabel(r'Photo thermal signal, self interf. ')
    ax.set_xlabel(r'$\hbar\omega$')
    plt.suptitle(r'$w_0 =$'+f' {round(w0):d} [nm] '+r'$\phi = $'+f' {phi:.2f}')
    return ax

def plot_probe_interf_terms_vs_energy(
    T_expansion, r_th, w0, phi, 
    V=1,
    ax=None,
    isolate_comp=None
    ):
    """ Lengths are input in nm
        """
    if ax is None:
        fig, ax = plt.subplots(1, 1)
    ## Get dielectric function and dn/dT
    fit_drude = cp.drude_lorentz_model(
            hws/hbar, 
            *temp_dep_eps_fits[f'{T_expansion:d}K']['x']
            )
    fit_dndT = dndt_array[:, T_expansion]

    (
        alpha0_term, 
        alphapi2_term, 
        alphaphi_term, 
        alphapi2phi_term
        ) = pti.ptsignal_probe_scat_interf_term(
            eps_c=fit_drude,
            eps_b=eps_back,
            a=a1*1e-7,
            b=w0*1e-7,
            r_th=r_th*1e-7,
            dndT_c= fit_dndT,
            phi=phi,
#             P_abs=None,
#             dndT_b=dndT_glycerol,
#             kappa=kappa_glycerol,
            V=V,
#             G_=1,
            return_components=True,
            )
    if (isolate_comp == 0) or (isolate_comp is None):
        ax.plot(
            hws.real,
            alpha0_term,
            label=r"$\alpha_\Omega^{(0)}$")
    if (isolate_comp == 1) or (isolate_comp is None):
        ax.plot(
            hws.real,
            alphapi2_term,
            label=r"$\alpha_\Omega^{\pi/2}$",
            ls='--')
    if (isolate_comp == 2) or (isolate_comp is None):
        ax.plot(
            hws.real,
            alphaphi_term,
            label=r"$\alpha_\Omega^{(\phi_{w_0})}$")
    if (isolate_comp == 3) or (isolate_comp is None):
        ax.plot(
            hws.real,
            alphapi2phi_term,
            label=r"$\alpha_\Omega^{(\pi/2+\phi_{w_0})}$",
            ls='--')
    if (isolate_comp is 'total') or (isolate_comp is None):
        ax.plot(
            hws.real,
            (  
                alpha0_term
                +alphapi2_term
                +alphaphi_term
                +alphapi2phi_term),
            label=r"sum",
            c='k')
    ax.legend(loc='center left')
    ax.set_ylabel(r'Photo thermal signal, probe interf. ')
    ax.set_xlabel(r'$\hbar\omega$')
    plt.suptitle(r'$w_0 =$'+f' {round(w0):d} [nm] '+r'$\phi = $'+f' {phi:.2f}')
    return ax

# %%
plot_self_interf_terms_vs_energy(T_expansion=0, r_th=2000, w0=500, phi=0)

# %%
plot_self_interf_terms_vs_energy(T_expansion=0, r_th=2000, w0=500, phi=np.pi/2)

# %%
plot_self_interf_terms_vs_energy(T_expansion=0, r_th=2000, w0=500, phi=np.pi)

# %%
plot_self_interf_terms_vs_energy(T_expansion=0, r_th=2000, w0=2000, phi=0)

# %%
def plot_self_interf_terms_vs_phase(T_expansion, r_th, w0, hw, phis=None):
    """ Lengths are input in nm
        """
    if phis is None:
        phis = np.linspace(0, 2*np.pi, 100)
    (
        alpha0_term, 
        alphapi2_term, 
        alphaphi_term, 
        alphapi2phi_term
        ) = pti.ptsignal_scattering_self_interf_term(
            eps_c=fit_drude,
            eps_b=eps_back,
            a=a1*1e-7,
            b=w0*1e-7,
            r_th=r_th*1e-7,
            dndT_c=fit_dndT,
            phi=phis,
#             P_abs=None,
#             dndT_b=dndT_glycerol,
#             kappa=kappa_glycerol,
#             E_probe=1,
#             G_=1,
            return_components=True,
            )
    
    plt.plot(
        phis,
        alpha0_term,
        label=r"$\alpha_\Omega^{(0)}$")
    plt.plot(
        phis,
        alphapi2_term,
        label=r"$\alpha_\Omega^{\pi/2}$",
        ls='--')
    plt.plot(
        phis,
        alphaphi_term,
        label=r"$\alpha_\Omega^{(\phi_{w_0})}$")
    plt.plot(
        phis,
        alphapi2phi_term,
        label=r"$\alpha_\Omega^{(\pi/2+\phi_{w_0})}$",
        ls='--')
    
    total = ( 
            alpha0_term
            +
            alphapi2_term
            +
            alphaphi_term
            +
            alphapi2phi_term
            )
    plt.plot(
        phis,
        total,
        label=r"sum",
        c='k')
    plt.legend(loc='center left')
    plt.ylabel(r'Photo thermal signal, self interf. ')
    plt.xlabel(r'$\phi$')
    plt.title(r'$w_0 =$'+f' {round(w0):d} [nm] '+r'$\hbar\omega = $'+f' {hw:.2f} [eV]')

    print(r"Max signal at $\phi =$ "+f"{phis[np.argmax(total)]}")
    
    
def get_self_interf_terms_vs_phase(T_expansion, r_th, w0, hw, phis=None):
    """ Lengths are input in nm
        """
    ## Get dielectric function and dn/dT
    fit_drude = cp.drude_lorentz_model(
            hw/hbar, 
            *temp_dep_eps_fits[f'{T_expansion:d}K']['x']
            )
    fit_dndT = dndt_array[pti.idx_nearest(hws, hw), T_expansion]

    if phis is None:
        phis = np.linspace(0, 2*np.pi, 100)
    (
        alpha0_term, 
        alphapi2_term, 
        alphaphi_term, 
        alphapi2phi_term
        ) = pti.ptsignal_scattering_self_interf_term(
            eps_c=fit_drude,
            eps_b=eps_back,
            a=a1*1e-7,
            b=w0*1e-7,
            r_th=r_th*1e-7,
            dndT_c=fit_dndT,
            phi=phis,
#             P_abs=None,
#             dndT_b=dndT_glycerol,
#             kappa=kappa_glycerol,
#             E_probe=1,
#             G_=1,
            return_components=True,
            )
    return alpha0_term, alphapi2_term, alphaphi_term, alphapi2phi_term

# %%
plot_self_interf_terms_vs_phase(T_expansion=0, r_th=2000, w0=2000, hw=1.8)
# Out:
# Max signal at $\phi =$ 3.744524577006016

# %%
plot_self_interf_terms_vs_energy(T_expansion=0, r_th=2000, w0=2000, phi=3.75)

# %%
plot_self_interf_terms_vs_phase(T_expansion=0, r_th=2000, w0=2000, hw=2.25)
# Out:
# Max signal at $\phi =$ 3.744524577006016

# %%
plot_self_interf_terms_vs_phase(T_expansion=0, r_th=2000, w0=400, hw=1.8)
# Out:
# Max signal at $\phi =$ 3.3002589492256416

# %%
plot_self_interf_terms_vs_energy(T_expansion=0, r_th=2000, w0=400, phi=3.3)

# %%
plot_self_interf_terms_vs_phase(T_expansion=0, r_th=500, w0=400, hw=1.8)
# Out:
# Max signal at $\phi =$ 3.6175915404973376

# %%
plot_self_interf_terms_vs_energy(T_expansion=0, r_th=500, w0=400, phi=3.62)

# %%
plot_self_interf_terms_vs_phase(T_expansion=0, r_th=500, w0=400, hw=2.35)
# Out:
# Max signal at $\phi =$ 3.6175915404973376

# %% [markdown]
# Try a side-by-side

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 3))
plot_self_interf_terms_vs_energy(T_expansion=0, r_th=2000, w0=500, phi=0, ax=axs[0])
plot_probe_interf_terms_vs_energy(T_expansion=0, r_th=2000, w0=500, phi=0, ax=axs[1])

# %%
plot_probe_interf_terms_vs_energy(T_expansion=0, r_th=2000, w0=500, phi=0, isolate_comp='total')

# %%
for i in range(4):
    plt.figure()
    plot_probe_interf_terms_vs_energy(T_expansion=0, r_th=2000, w0=500, phi=0, isolate_comp=i)

# %% [markdown]
# ### Calculation of the effective scattering volume for the transmitted probe field

# %%
def vol_x_Einc(hw, eps_b, probe_power=2e-4):
    
    k = (hw * eps_b**0.5 / hbar) / c

    V_times_Einc = np.sqrt(
        (3 * probe_power)
        /
        (c * k**4.))
    return V_times_Einc

# %%
plt.plot(hws, vol_x_Einc(hw=hws, eps_b=eps_back).real)

# %%
plot_probe_interf_terms_vs_energy(
    T_expansion=0, 
    r_th=2000, 
    w0=500, 
    phi=0, 
    V=vol_x_Einc(hw=hws, eps_b=eps_back),
    isolate_comp='total')

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 3))
plot_self_interf_terms_vs_energy(
    T_expansion=0,
    r_th=2000, 
    w0=500, 
    phi=0, 
    ax=axs[0])
plot_probe_interf_terms_vs_energy(
    T_expansion=0,
    r_th=2000,
    w0=500,
    phi=0,
    V=vol_x_Einc(hw=hws, eps_b=eps_back),
    ax=axs[1])

# %% [markdown]
# Sharing the y axis to compare terms

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 3), sharey=True)
plot_self_interf_terms_vs_energy(
    T_expansion=0,
    r_th=2000, 
    w0=500, 
    phi=0, 
    ax=axs[0])
plot_probe_interf_terms_vs_energy(
    T_expansion=0,
    r_th=2000,
    w0=500,
    phi=0,
    V=vol_x_Einc(hw=hws, eps_b=eps_back),
    ax=axs[1])
axs[0].set_title('Claire term')
axs[1].set_title('Lounis term')
# Out:
# Text(0.5, 1.0, 'Lounis term')

# %% [markdown]
# We have the hypothesis that the Claire term dominates for systems like the nanorod dimer. Can I push the model there to support this?
